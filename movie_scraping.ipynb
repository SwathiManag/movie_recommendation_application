# %%
import requests
import json
import pandas as pd

api_key = '4e9ae607a523010813557f75c871f4a5' # TMDB API key
base_url = 'https://api.themoviedb.org/3'
headers = {'Content-Type': 'application/json;charset=utf-8'}
movie_data = []

# loop through years from 1990 to 2022
for year in range(1990, 2023):
    # construct API URL to get movies released in a particular year
    url = f'{base_url}/discover/movie?api_key={api_key}&language=en-US&sort_by=popularity.desc&primary_release_year={year}'

    # make API request and get response
    response = requests.get(url, headers=headers)
    data = json.loads(response.text)
    
    # loop through results and get movie details
    for movie in data['results']:
        movie_id = movie['id']
        title = movie['title']
        release_date = movie['release_date']
        vote_average = movie['vote_average']
        overview = movie['overview']
        poster_path = movie['poster_path']
        
        # construct API URL to get additional movie details
        url = f'{base_url}/movie/{movie_id}?api_key={api_key}&language=en-US&append_to_response=credits'
        response = requests.get(url, headers=headers)
        data = json.loads(response.text)
        
        # get additional movie details
        budget = data['budget']
        genres = [genre['name'] for genre in data['genres']]
        runtime = data['runtime']
        revenue = data['revenue']
        actors = [actor['name'] for actor in data['credits']['cast']][:3]
        #print(data['credits']['crew'])
        director = [crew['name'] for crew in data['credits']['crew'] if crew['job'] == 'Director']
        #print(director)
        production_companies = [company['name'] for company in data['production_companies']]
        
        # append movie details to list
        movie_data.append({
            'id': movie_id,
            'director_name': director,         
            'actor_1_name': actors[0] if actors else "Unkown",
            'actor_2_name': actors[1] if (len(actors)>=2 and actors[1]) else "Unkown",
            'actor_3_name': actors[2] if (len(actors)>=3 and actors[2]) else "Unkown",
            'genres': genres,
            'movie_title': title,       
            'release_date': release_date,
            'vote_average': vote_average,
            'overview': overview,
            'poster_path': poster_path,
            'budget': budget,
            'runtime': runtime,
            'revenue': revenue,
            'production_companies': production_companies
        })

# %%
df = pd.DataFrame(movie_data)

# save dataframe to csv file
df.to_csv('movie_data.csv', index=False)

df.columns
# Out:
# Index(['id', 'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name',
#        'genres', 'movie_title', 'release_date', 'vote_average', 'overview',
#        'poster_path', 'budget', 'runtime', 'revenue', 'production_companies'],
#       dtype='object')

# %%
df.head()
# Out:
#       id       director_name      actor_1_name     actor_2_name  \
# 0  60898      [Lam Nai-Choi]  Pal Sinn Lap-man          Amy Yip
# 1  44281   [Férid Boughedir]   Selim Boughedir  Mustafa Adouani
# 2  39323  [Mitsuo Hashimoto]     Masako Nozawa  Kazuyuki Sogabe
# 3  39100    [Daisuke Nishio]     Masako Nozawa  Toshio Furukawa
# 4  39101    [Daisuke Nishio]     Masako Nozawa  Toshio Furukawa
#
#          actor_3_name                                             genres  \
# 0         Hitomi Kudô                           [Fantasy, Drama, Horror]
# 1  Rabia Ben Abdallah                                    [Comedy, Drama]
# 2           Yuko Mita  [Animation, Action, Science Fiction, Drama, Fa...
# 3       Mayumi Tanaka               [Action, Animation, Science Fiction]
# 4       Mayumi Tanaka               [Action, Animation, Science Fiction]
#
#                                    movie_title release_date  vote_average  \
# 0                           Erotic Ghost Story   1990-05-19           5.9
# 1              Halfaouine: Boy of the Terraces   1990-09-14           6.8
# 2  Dragon Ball Z: Bardock - The Father of Goku   1990-10-17           7.5
# 3         Dragon Ball Z: The World's Strongest   1990-03-10           6.5
# 4             Dragon Ball Z: The Tree of Might   1990-06-07           6.5
#
#                                             overview  \
# 0  Three vixens have meditated for 1,000 years to...
# 1  Twelve-year-old Noura dangles uncertainly in t...
# 2  Bardock, Son Goku's father, is a low-ranking S...
# 3  The evil Dr. Kochin uses the dragon balls to r...
# 4  Goku and friends must stop a band of space pir...
#
#                         poster_path  budget  runtime   revenue  \
# 0  /fTUCwsxVoLFuodAtlL6aITP1B45.jpg       0       88         0
# 1  /uI7hb9flZetd0KZoN2BGHLq4uvZ.jpg       0       98         0
# 2  /docwOsWZuwJKQdwcYJtQPBcg6bm.jpg       0       48         0
# 3  /5elbm3iLgGQ6nA5vqUmi9vIojbF.jpg       0       60  18000000
# 4  /fDX4Dp8IKvjBAaEb5MOJrGkxWX0.jpg       0       61  15000000
#
#                                 production_companies
# 0                                [Diagonal Pictures]
# 1  [Les Films du Scarabée, Cinétéléfilms, France ...
# 2       [Bird Studios, Toei Animation, Toei Company]
# 3                     [Toei Company, Toei Animation]
# 4                                   [Toei Animation]

# %%
c=['id', 'release_date','vote_average','overview','poster_path','runtime', 'revenue','budget','production_companies']
df.drop(labels=c,inplace=True,axis=1)

# %%
df['movie_title'] = df['movie_title'].str.lower()

# %%
df.head()
# Out:
#         director_name      actor_1_name     actor_2_name        actor_3_name  \
# 0      [Lam Nai-Choi]  Pal Sinn Lap-man          Amy Yip         Hitomi Kudô
# 1   [Férid Boughedir]   Selim Boughedir  Mustafa Adouani  Rabia Ben Abdallah
# 2  [Mitsuo Hashimoto]     Masako Nozawa  Kazuyuki Sogabe           Yuko Mita
# 3    [Daisuke Nishio]     Masako Nozawa  Toshio Furukawa       Mayumi Tanaka
# 4    [Daisuke Nishio]     Masako Nozawa  Toshio Furukawa       Mayumi Tanaka
#
#                                               genres  \
# 0                           [Fantasy, Drama, Horror]
# 1                                    [Comedy, Drama]
# 2  [Animation, Action, Science Fiction, Drama, Fa...
# 3               [Action, Animation, Science Fiction]
# 4               [Action, Animation, Science Fiction]
#
#                                    movie_title
# 0                           erotic ghost story
# 1              halfaouine: boy of the terraces
# 2  dragon ball z: bardock - the father of goku
# 3         dragon ball z: the world's strongest
# 4             dragon ball z: the tree of might

# %%
def get_director(x):
    return x[0] if len(x) else "unknown"


df['director_name'] = df['director_name'].apply(lambda x: get_director(x))

# %%
df['genres'] = df['genres'].apply(lambda x: ' '.join(x))

# %%
df.head()
# Out:
#       director_name      actor_1_name     actor_2_name        actor_3_name  \
# 0      Lam Nai-Choi  Pal Sinn Lap-man          Amy Yip         Hitomi Kudô
# 1   Férid Boughedir   Selim Boughedir  Mustafa Adouani  Rabia Ben Abdallah
# 2  Mitsuo Hashimoto     Masako Nozawa  Kazuyuki Sogabe           Yuko Mita
# 3    Daisuke Nishio     Masako Nozawa  Toshio Furukawa       Mayumi Tanaka
# 4    Daisuke Nishio     Masako Nozawa  Toshio Furukawa       Mayumi Tanaka
#
#                                            genres  \
# 0                            Fantasy Drama Horror
# 1                                    Comedy Drama
# 2  Animation Action Science Fiction Drama Fantasy
# 3                Action Animation Science Fiction
# 4                Action Animation Science Fiction
#
#                                    movie_title
# 0                           erotic ghost story
# 1              halfaouine: boy of the terraces
# 2  dragon ball z: bardock - the father of goku
# 3         dragon ball z: the world's strongest
# 4             dragon ball z: the tree of might

# %%
df['comb'] = df['actor_1_name'] + ' ' + df['actor_2_name'] + ' ' + df['actor_3_name'] + ' ' + df['director_name'] + ' ' + df['genres']

# %%
df.head()
# Out:
#       director_name      actor_1_name     actor_2_name        actor_3_name  \
# 0      Lam Nai-Choi  Pal Sinn Lap-man          Amy Yip         Hitomi Kudô
# 1   Férid Boughedir   Selim Boughedir  Mustafa Adouani  Rabia Ben Abdallah
# 2  Mitsuo Hashimoto     Masako Nozawa  Kazuyuki Sogabe           Yuko Mita
# 3    Daisuke Nishio     Masako Nozawa  Toshio Furukawa       Mayumi Tanaka
# 4    Daisuke Nishio     Masako Nozawa  Toshio Furukawa       Mayumi Tanaka
#
#                                            genres  \
# 0                            Fantasy Drama Horror
# 1                                    Comedy Drama
# 2  Animation Action Science Fiction Drama Fantasy
# 3                Action Animation Science Fiction
# 4                Action Animation Science Fiction
#
#                                    movie_title  \
# 0                           erotic ghost story
# 1              halfaouine: boy of the terraces
# 2  dragon ball z: bardock - the father of goku
# 3         dragon ball z: the world's strongest
# 4             dragon ball z: the tree of might
#
#                                                 comb
# 0  Pal Sinn Lap-man Amy Yip Hitomi Kudô Lam Nai-C...
# 1  Selim Boughedir Mustafa Adouani Rabia Ben Abda...
# 2  Masako Nozawa Kazuyuki Sogabe Yuko Mita Mitsuo...
# 3  Masako Nozawa Toshio Furukawa Mayumi Tanaka Da...
# 4  Masako Nozawa Toshio Furukawa Mayumi Tanaka Da...

# %%
df.tail()
# Out:
#            director_name           actor_1_name         actor_2_name  \
# 655           Scott Mann  Grace Caroline Currey     Virginia Gardner
# 656      Jacobo Martínez       María Romanillos            Ruth Díaz
# 657  Dean Fleischer Camp            Jenny Slate  Dean Fleischer Camp
# 658         Bobby Easley      Portia Chellelynn  Julie Anne Prescott
# 659        Taika Waititi        Chris Hemsworth      Natalie Portman
#
#             actor_3_name                                   genres  \
# 655  Jeffrey Dean Morgan                           Thriller Drama
# 656        Urko Olazábal                             Drama Horror
# 657  Isabella Rossellini  Animation Comedy Family Drama Adventure
# 658       Andrea Collins                                   Horror
# 659       Christian Bale                    Fantasy Action Comedy
#
#                         movie_title  \
# 655                            fall
# 656                    13 exorcisms
# 657  marcel the shell with shoes on
# 658    h.p. lovecraft's witch house
# 659          thor: love and thunder
#
#                                                   comb
# 655  Grace Caroline Currey Virginia Gardner Jeffrey...
# 656  María Romanillos Ruth Díaz Urko Olazábal Jacob...
# 657  Jenny Slate Dean Fleischer Camp Isabella Rosse...
# 658  Portia Chellelynn Julie Anne Prescott Andrea C...
# 659  Chris Hemsworth Natalie Portman Christian Bale...

# %%
df.to_csv("main_data.csv")

# %%
df['movie_title'][:15]
# Out:
# 0                              erotic ghost story
# 1                 halfaouine: boy of the terraces
# 2     dragon ball z: bardock - the father of goku
# 3            dragon ball z: the world's strongest
# 4                dragon ball z: the tree of might
# 5                                      predator 2
# 6                                       lionheart
# 7                                    pretty woman
# 8                          the godfather part iii
# 9                                      goodfellas
# 10                            edward scissorhands
# 11                                        tremors
# 12                                          ghost
# 13                                   total recall
# 14                                 child's play 2
# Name: movie_title, dtype: object
